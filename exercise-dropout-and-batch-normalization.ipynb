# %% [markdown]
# **This notebook is an exercise in the [Intro to Deep Learning](https://www.kaggle.com/learn/intro-to-deep-learning) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/dropout-and-batch-normalization).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In this exercise, you'll add dropout to the *Spotify* model from Exercise 4 and see how batch normalization can let you successfully train models on difficult datasets.
#
# Run the next cell to get started!

# %%
# Setup plotting
import matplotlib.pyplot as plt
from warnings import simplefilter
simplefilter('ignore')
plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.deep_learning_intro.ex5 import *

# %% [markdown]
# First load the *Spotify* dataset.

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.model_selection import GroupShuffleSplit

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import callbacks

spotify = pd.read_csv('../input/dl-course-data/spotify.csv')

X = spotify.copy().dropna()
y = X.pop('track_popularity')
artists = X['track_artist']

features_num = ['danceability', 'energy', 'key', 'loudness', 'mode',
                'speechiness', 'acousticness', 'instrumentalness',
                'liveness', 'valence', 'tempo', 'duration_ms']
features_cat = ['playlist_genre']

preprocessor = make_column_transformer(
    (StandardScaler(), features_num),
    (OneHotEncoder(), features_cat),
)

def group_split(X, y, group, train_size=0.75):
    splitter = GroupShuffleSplit(train_size=train_size)
    train, test = next(splitter.split(X, y, groups=group))
    return (X.iloc[train], X.iloc[test], y.iloc[train], y.iloc[test])

X_train, X_valid, y_train, y_valid = group_split(X, y, artists)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)
y_train = y_train / 100
y_valid = y_valid / 100

input_shape = [X_train.shape[1]]
print("Input shape: {}".format(input_shape))
# Out:
# Input shape: [18]

# %% [markdown]
# # 1) Add Dropout to Spotify Model
#
# Here is the last model from Exercise 4. Add two dropout layers, one after the `Dense` layer with 128 units, and one after the `Dense` layer with 64 units. Set the dropout rate on both to `0.3`.

# %%
# YOUR CODE HERE: Add two 30% dropout layers, one after 128 and one after 64
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=input_shape),
    layers.Dropout(rate = 0.3),
    layers.Dense(64, activation='relu'),
    layers.Dropout(rate = 0.3),
    layers.Dense(1),
])

# Check your answer
q_1.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_1.hint()
#q_1.solution()

# %% [markdown]
# Now run this next cell to train the model see the effect of adding dropout.

# %%
model.compile(
    optimizer='adam',
    loss='mae',
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=50,
    verbose=1,
)
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot()
print("Minimum Validation Loss: {:0.4f}".format(history_df['val_loss'].min()))
# Out:
# Epoch 1/50
# 50/50 [==============================] - 1s 7ms/step - loss: 0.1861 - val_loss: 0.1908
# Epoch 2/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1862 - val_loss: 0.1912
# Epoch 3/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1857 - val_loss: 0.1911
# Epoch 4/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.1856 - val_loss: 0.1910
# Epoch 5/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1857 - val_loss: 0.1910
# Epoch 6/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1863 - val_loss: 0.1910
# Epoch 7/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1857 - val_loss: 0.1908
# Epoch 8/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1853 - val_loss: 0.1909
# Epoch 9/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1854 - val_loss: 0.1911
# Epoch 10/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1853 - val_loss: 0.1912
# Epoch 11/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1852 - val_loss: 0.1913
# Epoch 12/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1854 - val_loss: 0.1913
# Epoch 13/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1855 - val_loss: 0.1915
# Epoch 14/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1858 - val_loss: 0.1914
# Epoch 15/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1850 - val_loss: 0.1915
# Epoch 16/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1854 - val_loss: 0.1913
# Epoch 17/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1856 - val_loss: 0.1913
# Epoch 18/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1847 - val_loss: 0.1916
# Epoch 19/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1847 - val_loss: 0.1915
# Epoch 20/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1843 - val_loss: 0.1914
# Epoch 21/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1845 - val_loss: 0.1914
# Epoch 22/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1851 - val_loss: 0.1913
# Epoch 23/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1849 - val_loss: 0.1915
# Epoch 24/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1847 - val_loss: 0.1914
# Epoch 25/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1844 - val_loss: 0.1913
# Epoch 26/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1847 - val_loss: 0.1914
# Epoch 27/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1846 - val_loss: 0.1918
# Epoch 28/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1840 - val_loss: 0.1918
# Epoch 29/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1846 - val_loss: 0.1914
# Epoch 30/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1845 - val_loss: 0.1917
# Epoch 31/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1840 - val_loss: 0.1916
# Epoch 32/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1841 - val_loss: 0.1915
# Epoch 33/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1842 - val_loss: 0.1917
# Epoch 34/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1844 - val_loss: 0.1921
# Epoch 35/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1843 - val_loss: 0.1917
# Epoch 36/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1838 - val_loss: 0.1919
# Epoch 37/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1838 - val_loss: 0.1918
# Epoch 38/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1843 - val_loss: 0.1920
# Epoch 39/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.1838 - val_loss: 0.1919
# Epoch 40/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.1842 - val_loss: 0.1915
# Epoch 41/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1834 - val_loss: 0.1918
# Epoch 42/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.1838 - val_loss: 0.1917
# Epoch 43/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.1837 - val_loss: 0.1916
# Epoch 44/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1835 - val_loss: 0.1916
# Epoch 45/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.1832 - val_loss: 0.1918
# Epoch 46/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1830 - val_loss: 0.1919
# Epoch 47/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1839 - val_loss: 0.1913
# Epoch 48/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1833 - val_loss: 0.1916
# Epoch 49/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1834 - val_loss: 0.1912
# Epoch 50/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1832 - val_loss: 0.1916
# Minimum Validation Loss: 0.1908

# %% [markdown]
# # 2) Evaluate Dropout
#
# Recall from Exercise 4 that this model tended to overfit the data around epoch 5. Did adding dropout seem to help prevent overfitting this time?

# %%
# View the solution (Run this cell to receive credit!)
q_2.check()
# Out:
# Correct:
#
#
# From the learning curves, you can see that the validation loss remains near a constant minimum even though the training loss continues to decrease. So we can see that adding dropout did prevent overfitting this time. Moreover, by making it harder for the network to fit spurious patterns, dropout may have encouraged the network to seek out more of the true patterns, possibly improving the validation loss some as well).

# %% [markdown]
# Now, we'll switch topics to explore how batch normalization can fix problems in training.
#
# Load the *Concrete* dataset. We won't do any standardization this time. This will make the effect of batch normalization much more apparent.

# %%
import pandas as pd

concrete = pd.read_csv('../input/dl-course-data/concrete.csv')
df = concrete.copy()

df_train = df.sample(frac=0.7, random_state=0)
df_valid = df.drop(df_train.index)

X_train = df_train.drop('CompressiveStrength', axis=1)
X_valid = df_valid.drop('CompressiveStrength', axis=1)
y_train = df_train['CompressiveStrength']
y_valid = df_valid['CompressiveStrength']

input_shape = [X_train.shape[1]]

# %% [markdown]
# Run the following cell to train the network on the unstandardized *Concrete* data.

# %%
model = keras.Sequential([
    layers.Dense(512, activation='relu', input_shape=input_shape),
    layers.Dense(512, activation='relu'),    
    layers.Dense(512, activation='relu'),
    layers.Dense(1),
])
model.compile(
    optimizer='sgd', # SGD is more sensitive to differences of scale
    loss='mae',
    metrics=['mae'],
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=64,
    epochs=100,
    verbose=1,
)

history_df = pd.DataFrame(history.history)
history_df.loc[0:, ['loss', 'val_loss']].plot()
print(("Minimum Validation Loss: {:0.4f}").format(history_df['val_loss'].min()))
# Out:
# Epoch 1/100
# 12/12 [==============================] - 1s 29ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 2/100
# 12/12 [==============================] - 0s 10ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 3/100
# 12/12 [==============================] - 0s 10ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 4/100
# 12/12 [==============================] - 0s 10ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 5/100
# 12/12 [==============================] - 0s 10ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 6/100
# 12/12 [==============================] - 0s 11ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 7/100
# 12/12 [==============================] - 0s 10ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 8/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 9/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 10/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 11/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 12/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 13/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 14/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 15/100
# 12/12 [==============================] - 0s 8ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 16/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 17/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 18/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 19/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 20/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 21/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 22/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 23/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 24/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 25/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 26/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 27/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 28/100
# 12/12 [==============================] - 0s 8ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 29/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 30/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 31/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 32/100
# 12/12 [==============================] - 0s 8ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 33/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 34/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 35/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 36/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 37/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 38/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 39/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 40/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 41/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 42/100
# 12/12 [==============================] - 0s 8ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 43/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 44/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 45/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 46/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 47/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 48/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 49/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 50/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 51/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 52/100
# 12/12 [==============================] - 0s 8ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 53/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 54/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 55/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 56/100
# 12/12 [==============================] - 0s 8ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 57/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 58/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 59/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 60/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 61/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 62/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 63/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 64/100
# 12/12 [==============================] - 0s 8ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 65/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 66/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 67/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 68/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 69/100
# 12/12 [==============================] - 0s 8ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 70/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 71/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 72/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 73/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 74/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 75/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 76/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 77/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 78/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 79/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 80/100
# 12/12 [==============================] - 0s 8ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 81/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 82/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 83/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 84/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 85/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 86/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 87/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 88/100
# 12/12 [==============================] - 0s 8ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 89/100
# 12/12 [==============================] - 0s 8ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 90/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 91/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 92/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 93/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 94/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 95/100
# 12/12 [==============================] - 0s 10ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 96/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 97/100
# 12/12 [==============================] - 0s 7ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 98/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 99/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Epoch 100/100
# 12/12 [==============================] - 0s 6ms/step - loss: nan - mae: nan - val_loss: nan - val_mae: nan
# Minimum Validation Loss: nan

# %% [markdown]
# Did you end up with a blank graph? Trying to train this network on this dataset will usually fail. Even when it does converge (due to a lucky weight initialization), it tends to converge to a very large number.
#
# # 3) Add Batch Normalization Layers
#
# Batch normalization can help correct problems like this.
#
# Add four `BatchNormalization` layers, one before each of the dense layers. (Remember to move the `input_shape` argument to the new first layer.)

# %%
# YOUR CODE HERE: Add a BatchNormalization layer before each Dense layer
model = keras.Sequential([
    layers.BatchNormalization(),
    layers.Dense(512, activation='relu', input_shape=input_shape),
    layers.BatchNormalization(),
    layers.Dense(512, activation='relu'),
    layers.BatchNormalization(),
    layers.Dense(512, activation='relu'),
    layers.BatchNormalization(),
    layers.Dense(1),
])

# Check your answer
q_3.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_3.hint()
#q_3.solution()

# %% [markdown]
# Run the next cell to see if batch normalization will let us train the model.

# %%
model.compile(
    optimizer='sgd',
    loss='mae',
    metrics=['mae'],
)
EPOCHS = 100
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=64,
    epochs=EPOCHS,
    verbose=1,
)

history_df = pd.DataFrame(history.history)
history_df.loc[0:, ['loss', 'val_loss']].plot()
print(("Minimum Validation Loss: {:0.4f}").format(history_df['val_loss'].min()))
# Out:
# Epoch 1/100
# 12/12 [==============================] - 2s
100
# 12/12 [==============================] - 0s 10ms/step - loss: 3.1760 - mae: 3.1760 - val_loss: 5.3595 - val_mae: 5.3595
# Epoch 79/100
# 12/12 [==============================] - 0s 9ms/step - loss: 4.1826 - mae: 4.1826 - val_loss: 4.7597 - val_mae: 4.7597
# Epoch 80/100
# 12/12 [==============================] - 0s 9ms/step - loss: 3.3368 - mae: 3.3368 - val_loss: 4.5719 - val_mae: 4.5719
# Epoch 81/100
# 12/12 [==============================] - 0s 10ms/step - loss: 3.8836 - mae: 3.8836 - val_loss: 4.7170 - val_mae: 4.7170
# Epoch 82/100
# 12/12 [==============================] - 0s 10ms/step - loss: 3.9506 - mae: 3.9506 - val_loss: 5.0720 - val_mae: 5.0720
# Epoch 83/100
# 12/12 [==============================] - 0s 10ms/step - loss: 3.5208 - mae: 3.5208 - val_loss: 4.1675 - val_mae: 4.1675
# Epoch 84/100
# 12/12 [==============================] - 0s 9ms/step - loss: 3.3414 - mae: 3.3414 - val_loss: 4.6817 - val_mae: 4.6817
# Epoch 85/100
# 12/12 [==============================] - 0s 9ms/step - loss: 3.9277 - mae: 3.9277 - val_loss: 4.8568 - val_mae: 4.8568
# Epoch 86/100
# 12/12 [==============================] - 0s 10ms/step - loss: 3.5715 - mae: 3.5715 - val_loss: 4.9642 - val_mae: 4.9642
# Epoch 87/100
# 12/12 [==============================] - 0s 9ms/step - loss: 3.5255 - mae: 3.5255 - val_loss: 4.5564 - val_mae: 4.5564
# Epoch 88/100
# 12/12 [==============================] - 0s 9ms/step - loss: 3.9222 - mae: 3.9222 - val_loss: 4.7659 - val_mae: 4.7659
# Epoch 89/100
# 12/12 [==============================] - 0s 10ms/step - loss: 3.2943 - mae: 3.2943 - val_loss: 4.5711 - val_mae: 4.5711
# Epoch 90/100
# 12/12 [==============================] - 0s 10ms/step - loss: 3.4461 - mae: 3.4461 - val_loss: 4.2928 - val_mae: 4.2928
# Epoch 91/100
# 12/12 [==============================] - 0s 9ms/step - loss: 3.7874 - mae: 3.7874 - val_loss: 5.0432 - val_mae: 5.0432
# Epoch 92/100
# 12/12 [==============================] - 0s 9ms/step - loss: 3.0853 - mae: 3.0853 - val_loss: 5.2090 - val_mae: 5.2090
# Epoch 93/100
# 12/12 [==============================] - 0s 9ms/step - loss: 3.1818 - mae: 3.1818 - val_loss: 4.6790 - val_mae: 4.6790
# Epoch 94/100
# 12/12 [==============================] - 0s 10ms/step - loss: 3.1779 - mae: 3.1779 - val_loss: 4.0445 - val_mae: 4.0445
# Epoch 95/100
# 12/12 [==============================] - 0s 9ms/step - loss: 3.1787 - mae: 3.1787 - val_loss: 4.7953 - val_mae: 4.7953
# Epoch 96/100
# 12/12 [==============================] - 0s 9ms/step - loss: 3.4482 - mae: 3.4482 - val_loss: 4.2811 - val_mae: 4.2811
# Epoch 97/100
# 12/12 [==============================] - 0s 9ms/step - loss: 3.3335 - mae: 3.3335 - val_loss: 4.2895 - val_mae: 4.2895
# Epoch 98/100
# 12/12 [==============================] - 0s 11ms/step - loss: 3.3596 - mae: 3.3596 - val_loss: 4.4228 - val_mae: 4.4228
# Epoch 99/100
# 12/12 [==============================] - 0s 11ms/step - loss: 3.3938 - mae: 3.3938 - val_loss: 5.0615 - val_mae: 5.0615
# Epoch 100/100
# 12/12 [==============================] - 0s 16ms/step - loss: 3.5105 - mae: 3.5105 - val_loss: 4.5496 - val_mae: 4.5496
# Minimum Validation Loss: 3.8572

# %% [markdown]
# # 4) Evaluate Batch Normalization
#
# Did adding batch normalization help?

# %%
# View the solution (Run this cell to receive credit!)
q_4.check()
# Out:
# Correct:
#
#
# You can see that adding batch normalization was a big improvement on the first attempt! By adaptively scaling the data as it passes through the network, batch normalization can let you train models on difficult datasets.

# %% [markdown]
# # Keep Going #
#
# [**Create neural networks**](https://www.kaggle.com/ryanholbrook/binary-classification) for binary classification.

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/intro-to-deep-learning/discussion) to chat with other learners.*
